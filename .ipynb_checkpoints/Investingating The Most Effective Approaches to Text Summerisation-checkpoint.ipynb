# %% [markdown]
# # Hybrid Summarization Methods: A Comparative Analysis

# %% [markdown]
# ## Abstract
#
# In the pursuit of efficient summarization techniques, a hybrid approach that combines extractive and abstractive methods has been proposed. This document aims to analyze various combinations of these methods to determine the most effective hybrid approach for summarizing documents while maintaining accuracy, relevance, clarity, and cohesiveness.

# %% [markdown]
# ## Introduction
#
# Summarization algorithms can be broadly categorized into two types: extractive and abstractive. Extractive summarization methods identify key sentences or fragments in the text and compile them to form a summary. In contrast, abstractive summarization methods generate new sentences, often rephrasing or interpreting the original content to produce a concise version.

# %% [markdown]
# ## Methodology
#
# In this research, a methodical first-principles approach was employed to critically evaluate and compare hybrid summarization methods, integrating the precision of extractive techniques with the narrative quality of abstractive methods. Initially, a deep dive into the core principles of each method informed the creation of five theoretically sound hybrid models. These models were empirically tested against performance metrics—accuracy, relevance, clarity, and cohesiveness—and subsequently underwent a rigorous critical analysis to assess their practical application and the validity of the results. The culmination of this process was a logical synthesis of the evidence, leading to the selection of the most effective hybrid model for summarization, ensuring that the conclusions were as robust in practice as they were in theory.

# %%
import tkinter as tk
from tkinter import filedialog
# Initialize the Tkinter GUI
root = tk.Tk()
root.withdraw()  # Hide the root window

# Choose a file
def choose_file():
    file_path = filedialog.askopenfilename(filetypes=[("PDF files", "*.pdf")])  # Only allow PDFs
    return file_path

# %%
#!pip install "unstructured[pdf]"

# %% [markdown]
# ## Text Extraction and Preprocessing
# The first step in text summarization is to extract the text from the source, which in this case is a PDF document. After extraction, the text is preprocessed to facilitate further analysis. This involves tokenizing the text into sentences and words, removing stopwords (common words that do not contribute much meaning), and stemming (reducing words to their root form).

# %%
from pdfminer.high_level import extract_text
from unstructured.partition.pdf import partition_pdf
from unstructured.chunking.title import chunk_by_title
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

from pdfminer.high_level import extract_text

# Extract text from PDF
def extract_text_from_pdf(pdf_path):
    return extract_text(pdf_path)

# Preprocess text
def preprocess_text(text):
    nltk.download('punkt')
    nltk.download('stopwords')
    
    stop_words = set(stopwords.words('english'))
    stemmer = PorterStemmer()
    
    sentences = sent_tokenize(text)
    preprocessed_text = []
    for sentence in sentences:
        tokens = [stemmer.stem(word) for word in word_tokenize(sentence.lower())
                  if word not in stop_words and word.isalnum()]
        if tokens:
            preprocessed_text.append(tokens)
    
    sentences = [sentences[i] for i, tokens in enumerate(preprocessed_text) if tokens]
    
    return sentences, preprocessed_text

# %% [markdown]
# ## Building the Similarity Matrix
# The similarity matrix is a crucial component in the TextRank algorithm. It represents the similarity between different sentences in the text. A common approach is to use vector representations of sentences and calculate the cosine similarity between these vectors. For this purpose, we train a Word2Vec model on the preprocessed text. The similarity matrix is then constructed by calculating the cosine similarity between the vector representations of all pairs of sentences.

# %%
import numpy as np
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity

# Build similarity matrix for TextRank
def build_similarity_matrix(sentences, preprocessed_text):
    model = Word2Vec(preprocessed_text, vector_size=100, window=2, min_count=1, workers=2)
    model_wv = model.wv
    
    sim_matrix = np.zeros((len(sentences), len(sentences)))
    
    for i in range(len(sentences)):
        for j in range(len(sentences)):
            if i != j and preprocessed_text[i] and preprocessed_text[j]:
                vector_i = np.mean([model_wv[word] for word in preprocessed_text[i] if word in model_wv], axis=0)
                vector_j = np.mean([model_wv[word] for word in preprocessed_text[j] if word in model_wv], axis=0)
                if not (np.any(np.isnan(vector_i)) or np.any(np.isnan(vector_j)) or np.any(np.isinf(vector_i)) or np.any(np.isinf(vector_j))):
                    sim_matrix[i][j] = cosine_similarity([vector_i], [vector_j])[0, 0]
    
    return sim_matrix

# %% [markdown]
# ## Applying TextRank
# TextRank is an algorithm based on the PageRank algorithm used by Google for ranking web pages. In the context of text summarization, it ranks sentences based on their importance within the text. The apply_text_rank function applies the TextRank algorithm to the similarity matrix, using the networkx library's implementation of PageRank. If the algorithm fails to converge, we dynamically adjust the tolerance and iteration count, and as a last resort, we use degree centrality as a fallback strategy.

# %%
import networkx as nx

# Apply TextRank to the similarity matrix
def apply_text_rank(sim_matrix, sentences):
    normalized_sim_matrix = normalize_similarity_matrix(sim_matrix)
    
    nx_graph = nx.from_numpy_array(normalized_sim_matrix)
    tolerance = 1e-3
    max_iter = 1000
    scores = None

    for attempt in range(5):
        try:
            scores = nx.pagerank(nx_graph, max_iter=max_iter, tol=tolerance)
            break
        except nx.PowerIterationFailedConvergence:
            tolerance *= 10
            max_iter *= 2

    if scores is None:
        print("PageRank failed to converge, using fallback strategy.")
        scores = nx.degree_centrality(nx_graph)

    ranked_sentences = sorted(((scores[i], s) for i, s in enumerate(sentences)), reverse=True)
    return [s for score, s in ranked_sentences]

# Normalize the similarity matrix
def normalize_similarity_matrix(sim_matrix):
    row_sums = sim_matrix.sum(axis=1)
    normalized_matrix = np.divide(sim_matrix, row_sums[:, np.newaxis], where=row_sums[:, np.newaxis] != 0)
    return normalized_matrix

# %% [markdown]
# ## Integration of T5 for Summarization
# The T5 (Text-to-Text Transfer Transformer) model is a powerful NLP tool capable of performing various text-based tasks, including summarization. The code integrates T5 to refine the summary produced by TextRank. It first prepares the text by prefixing it with "summarize:" and then encodes it using the T5 tokenizer. The T5 model then generates a summary that is concise and relevant.

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

# Load T5 model and tokenizer
model_name = 't5-base'  
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

# Prepare text for T5
def prepare_text_for_t5(text):
    preprocessed_text = "summarize: " + text
    return tokenizer.encode(preprocessed_text, return_tensors="pt", max_length=512, truncation=True)

# Summarize text with T5
def summarize_with_t5(encoded_text):
    summary_ids = model.generate(encoded_text, min_length=30, max_length=200, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary
# Out:
# C:\Users\wasim\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\t5\tokenization_t5.py:240: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 694766da-8580-4c5b-a5d8-6498442a4bf3)')' thrown while requesting HEAD https://huggingface.co/t5-base/resolve/main/config.json

# %% [markdown]
# ## Creating a final Summary
# This is the final summary created

# %%
# Other imports and function definitions remain unchanged...

# Main function to summarize each paragraph
def final_summary(pdf_path):
    print("Starting text extraction from PDF...")
    text = extract_text_from_pdf(pdf_path)
    print("Extraction complete. Preprocessing text...")

    paragraphs = text.split('\n\n')
    filtered_paragraphs = [paragraph for paragraph in paragraphs if len(paragraph.split()) >= 50]

    print(f"Number of paragraphs extracted: {len(filtered_paragraphs)}")
    summaries = []

    for paragraph in filtered_paragraphs:
        print("Preparing paragraph for T5 summarization...")
        encoded_text = prepare_text_for_t5(paragraph)
        print("Paragraph prepared for T5.")

        print("Generating summary for paragraph with T5...")
        summary = summarize_with_t5(encoded_text)
        print("Summary generated for paragraph with T5.")

        summaries.append(summary)

    # Combine all paragraph summaries into one final document summary
    final_summary = ' '.join(summaries)
    print("All paragraphs summarized. Final summary created.")

    return final_summary

# %%
# Run the hybrid summarizer
T5_summary = final_summary(pdf_path)
print(T5_summary)
# Out:
# Starting text extraction from PDF...
# Extraction complete. Preprocessing text...
# Number of paragraphs extracted: 13
# Preparing paragraph for T5 summarization...
# Paragraph prepared for T5.
# Generating summary for paragraph with T5...
# Summary generated for paragraph with T5.
# Preparing paragraph for T5 summarization...
# Paragraph prepared for T5.
# Generating summary for paragraph with T5...
# Summary generated for paragraph with T5.
# Preparing paragraph for T5 summarization...
# Paragraph prepared for T5.
# Generating summary for paragraph with T5...
# Summary generated for paragraph with T5.
# Preparing paragraph for T5 summarization...
# Paragraph prepared for T5.
# Generating summary for paragraph with T5...
# Summary generated for paragraph with T5.
# Preparing paragraph for T5 summarization...
# Paragraph prepared for T5.
# Generating summary for paragraph with T5...
# Summary generated for paragraph with T5.
# Preparing paragraph for T5 summarization...
# Paragraph prepared for T5.
# Generating summary for paragraph with T5...
# Summary generated for paragraph with T5.
# Preparing paragraph for T5 summarization...
# Paragraph prepared for T5.
# Generating summary for paragraph with T5...
# Summary generated for paragraph with T5.
# Preparing paragraph for T5 summarization...
# Paragraph prepared for T5.
# Generating summary for paragraph with T5...
# Summary generated for paragraph with T5.
# Preparing paragraph for T5 summarization...
# Paragraph prepared for T5.
# Generating summary for paragraph with T5...
# Summary generated for paragraph with T5.
# Preparing paragraph for T5 summarization...
# Paragraph prepared for T5.
# Generating summary for paragraph with T5...
# Summary generated for paragraph with T5.
# Preparing paragraph for T5 summarization...
# Paragraph prepared for T5.
# Generating summary for paragraph with T5...
# Summary generated for paragraph with T5.
# Preparing paragraph for T5 summarization...
# Paragraph prepared for T5.
# Generating summary for paragraph with T5...
# Summary generated for paragraph with T5.
# Preparing paragraph for T5 summarization...
# Paragraph prepared for T5.
# Generating summary for paragraph with T5...
# Summary generated for paragraph with T5.
# All paragraphs summarized. Final summary created.
# the purpose of this brief commentary is to provide a brief overview of Weber’s life, work, and contributions to management thought. the commentary begins with a brief biographical sketch followed by an examination of Weber’s conceptualization of authority, its influence on the field of management and its relevancy in the twenty-first century. some organizational theorists have questioned the relevancy of Weber’s theories in today’s late-modern knowledge-based information age. a complete examination of the enduring influence of the entire breadth of Weber’s writings in the current context is well beyond the scope of this brief commentary. Max Weber was born in 1864 in Erfurt, Germany, the oldest of eight children. he studied law at the university of Heidelberg before completing his doctoral dissertation. his academic career would span law, history, economics, philosophy, and sociology. in 1904, after a five-year period during which he published virtually nothing, Weber began publishing some of his most influential essays. these essays were later collected to comprise his most influential book, The Protestant Ethic and the Spirit of Capitalism. his influence on management thought following his death was slowed somewhat by a lack of English translations of his work. Weber forwarded three basic types of authority: traditional, rational-legal, and charismatic. charismatic authority results from extraordinary personal characteristics of a leader that have the capacity to inspire others. weber saw three types of authority as forces that would bring stability and order. legal/rational and charismatic authority are forms of rebellion against status quo. charismatic authority is transitory and unstable, most effective in times of crisis, he says. modern organizations are increasingly characterized by new, decentralized network-based structures that are quite different from large, complex bureaucracies of Weber’s day. knowledge-based work and cutting-edge technologies are creating new organizational realities centered on concepts such as telecommuting, empowerment, and self-managing teams. weber redefined the term "charisma" to mean "a special quality of an individual capable of inspiring and influencing others" his writings on charismatic authority have served as the conceptual basis for the development of theoretical models of charismatic leadership. conger (1993) called for researchers to examine the routinization of charismatic leadership. leadership theorists have generally suggested that times of stress, turbulence, and rapid change are more conducive to a charismatic leadership approach. Weber (1968) himself focused specifically on times of crisis as a primary facilitating environment for charismatic authority. participatory organizational forms and practices may simply represent a shift in the locus of control from managers in traditional bureaucratic structures to the workers themselves. workers become accountable to their teammates and to themselves rather than to a relatively distant manager. the development of charismatic leadership was in part responsible for rejuvenating the study of leadership. if this is true, then the field of leadership was to a large extent rejuvenated by the influence of Max Weber. Jeffery D. Houghton is an associate professor of management. he has presented his research at various professional meetings. he holds a PhD in organizational studies from vpi and state university. this article has been cited by:1.Kate Maclean. 2017. Disarming charisma? Mayoralty, gender and power in Medelln, Colombia. PoliticalGeography 59, 126-135. [Crossref]2.Edna Rabenu. Positive Psychological Capital: From Strengths to Power 81-105. [Crossref]3.Colleen Schwarz. 2015. A review of management history from 2010-2014 utilizingathematic analysis.

# %%
#!pip install language_tool_python

# %%
import language_tool_python
tool = language_tool_python.LanguageTool('en-UK')
matches = tool.check(T5_summary)
corrected_text = language_tool_python.utils.correct(T5_summary, matches)
print(corrected_text)
# Out:
# The purpose of this brief commentary is to provide a brief overview of Weber’s life, work, and contributions to management thought. The commentary begins with a brief biographical sketch followed by an examination of Weber’s conceptualization of authority, its influence on the field of management and its relevancy in the twenty-first century. Some organizational theorists have questioned the relevancy of Weber’s theories in today’s late-modern knowledge-based information age. A complete examination of the enduring influence of the entire breadth of Weber’s writings in the current context is well beyond the scope of this brief commentary. Max Weber was born in 1864 in Erfurt, Germany, the oldest of eight children. He studied law at the university of Heidelberg before completing his doctoral dissertation. His academic career would span law, history, economics, philosophy, and sociology. In 1904, after a five-year period during which he published virtually nothing, Weber began publishing some of his most influential essays. These essays were later collected to comprise his most influential book, The Protestant Ethic and the Spirit of Capitalism. His influence on management thought following his death was slowed somewhat by a lack of English translations of his work. Weber forwarded three basic types of authority: traditional, rational-legal, and charismatic. Charismatic authority results from extraordinary personal characteristics of a leader that have the capacity to inspire others. Weber saw three types of authority as forces that would bring stability and order. Legal/rational and charismatic authority are forms of rebellion against status quo. Charismatic authority is transitory and unstable, most effective in times of crisis, he says. Modern organizations are increasingly characterized by new, decentralized network-based structures that are quite different from large, complex bureaucracies of Weber’s day. Knowledge-based work and cutting-edge technologies are creating new organizational realities centered on concepts such as telecommuting, empowerment, and self-managing teams. Weber redefined the term "charisma" to mean "a special quality of an individual capable of inspiring and influencing others" his writings on charismatic authority have served as the conceptual basis for the development of theoretical models of charismatic leadership. Conger (1993) called for researchers to examine the routinization of charismatic leadership. Leadership theorists have generally suggested that times of stress, turbulence, and rapid change are more conducive to a charismatic leadership approach. Weber (1968) himself focused specifically on times of crisis as a primary facilitating environment for charismatic authority. Participatory organizational forms and practices may simply represent a shift in the locus of control from managers in traditional bureaucratic structures to the workers themselves. Workers become accountable to their teammates and to themselves rather than to a relatively distant manager. The development of charismatic leadership was in part responsible for rejuvenating the study of leadership. If this is true, then the field of leadership was to a large extent rejuvenated by the influence of Max Weber. Jeffery D. Houghton is an associate professor of management. He has presented his research at various professional meetings. He holds a PhD in organizational studies from vpi and state university. This article has been cited by:1. Kate Maclean. 2017. Disarming charisma? Mayoralty, gender and power in Medelln, Colombia. PoliticalGeography 59, 126-135. [Crossref]2. Edna Rabenu. Positive Psychological Capital: From Strengths to Power 81-105. [Crossref]3. Colleen Schwarz. 2015. A review of management history from 2010-2014 utilizingathematic analysis.

# %% [markdown]
# ## gpt-4 + K-Mean clusters approach

# %%
import os 
import openai
from pdfminer.high_level import extract_text
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from langchain.embeddings import OpenAIEmbeddings
from langchain import LLMChain, PromptTemplate
import os
from langchain import LLMChain
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains.mapreduce import MapReduceChain
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains import (
                StuffDocumentsChain,
                LLMChain,
                ReduceDocumentsChain,
                MapReduceDocumentsChain,
            )
# Extract text from PDF and remove short paragraphs
def extract_text_from_pdf(pdf_path):
    text = extract_text(pdf_path)
    paragraphs = text.split('\n\n')
    filtered_paragraphs = [p for p in paragraphs if len(p.split()) >= 50]
    return '\n\n'.join(filtered_paragraphs)

# Replace 'your_pdf_path.pdf' with the actual path to your PDF file

pdf_path = choose_file()
pdf_text = extract_text_from_pdf(pdf_path)

# Assume pdf_text is a list of paragraphs or sentences
df = pd.DataFrame({'text': pdf_text.split('\n\n')})

# Embedding
os.environ["OPENAI_API_KEY"] = "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"
embeddings = OpenAIEmbeddings()
df['embedding'] = df['text'].apply(lambda x: embeddings.embed_query(x))

# Clustering
n_clusters = 10  # or another number based on your data
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
df['Cluster'] = kmeans.fit_predict(list(df['embedding']))

# Summarization with GPT-4 Turbo
map_template = """The following is a set of documents
{docs}
Based on this list of docs, please identify the key concepts conveyed
Helpful Answer:"""
map_prompt = PromptTemplate.from_template(map_template)
llm = LLMChain(llm=ChatOpenAI(model_name="gpt-4-1106-preview"), prompt=map_prompt)  # Define your prompt template

def summarize_cluster(cluster_texts):
    # Combine texts and pass to GPT-4 for summarization
    combined_text = "\n".join(cluster_texts)
    return llm.run(combined_text)

# Apply summarization to each cluster
cluster_summaries = df.groupby('Cluster')['text'].apply(summarize_cluster)

# Print or process the summaries
for cluster_id, summary in cluster_summaries.iteritems():
    print(f"Cluster {cluster_id} Summary:")
    print(summary)
    print("\n" + "="*80 + "\n")
    
# Aggregate cluster summaries
all_summaries = [summary for cluster_id, summary in cluster_summaries.iteritems()]

# Combine all summaries into one text
combined_summaries = "\n".join(all_summaries)
# Out:
# C:\Users\wasim\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster 0 Summary:
# The key concepts conveyed in this set of documents include:
#
# 1. **Charisma in Emergencies**: Bendix (1977) suggests that charisma tends to emerge or become more apparent during emergency situations. This implies that in times of crisis, individuals with charismatic qualities are more likely to be recognized or to assume leadership roles due to their ability to inspire or mobilize people.
#
# 2. **Abnormal Conditions and Charisma**: Mommsen (1974) points out that the purest form of charisma is often linked to abnormal situations. This concept aligns with the idea that charisma is not a common feature of everyday life but rather something that stands out or becomes evident in extraordinary circumstances.
#
# 3. **Disruption of Everyday Life**: Schluchter (1988) argues that charisma becomes particularly sought after when normalcy is significantly disrupted. This concept suggests that when the routine structure of life is shattered, people tend to look for individuals who exhibit exceptional qualities or competencies to guide them through the uncertain period.
#
# Overall, the key concepts revolve around the relationship between charisma and unusual or crisis situations. Charismatic leadership is associated with times when stability is compromised, and there is a collective need for extraordinary guidance and reassurance.
#
# ================================================================================
#
# Cluster 1 Summary:
# The key concepts conveyed in the provided text are as follows:
#
# 1. Western Rationality: Max Weber's focus on the rise of Western rationality as a central theme in his works, particularly in his analyses of Protestant ethics and other scholarly writings.
#
# 2. Disenchantment with the Irrational: Weber's initial indifference or even discomfort with what he considered 'irrational', including religion and poetry, as indicated by his self-professed 'unmusical' nature towards religious matters.
#
# 3. Transformation in Weber's Reception of Art and Literature: A notable change in Weber’s attitude towards the arts and literature after recovering from an illness, with an increased appreciation for poets like Stefan George and Rainer Maria Rilke, and Russian writers such as Dostoevsky and Tolstoy.
#
# 4. Charisma and Charismatic Leadership: Weber's concept of charismatic leaders, such as Stefan George and Leo Tolstoy, whom he considered 'irrational' in certain respects, and his intent to discuss this concept in relation to other types of leadership.
#
# 5. Ethics of Conviction: Weber's description of an unconditional ethical stance, exemplified by figures like Jesus, Luther, and characters from Dostoevsky and Tolstoy’s writings, who acted without regard for the consequences of their actions.
#
# 6. Realpolitik and the Ethics of Responsibility: Weber's belief that politicians must deal with the 'realities of life', which might necessitate the use of power and force, contrasting with the ethics of conviction.
#
# 7. The Problem of 'Personalities': Weber's concern with the authenticity of 'personalities', distinguishing between true personalities like Goethe and false ones he refers to as 'idols'.
#
# 8. The Concept of 'Erlebnis': Weber's use of the term 'Erlebnis' to denote an intense or even artificial experience, as opposed to ordinary experience or mere 'sensation'.
#
# These concepts reflect Weber's intellectual journey and his thoughts on rationality, leadership, ethics, and the role of personal authenticity in social and political life.
#
# ================================================================================
#
# Cluster 2 Summary:
# From the provided text, the key concepts conveyed relate to Max Weber's analysis of types of authority and their characteristics within a society. Here are the key concepts:
#
# 1. **Types of Legitimate Authority**: Weber identifies three main types of legitimate authority in society:
#    - **Legal Authority**: This is characterized by a system of rules and regulations that govern behavior. Bureaucratic authority is the purest form of legal authority.
#    - **Traditional Authority**: This is based on long-standing customs, traditions, and established practices. It involves a respect for the sanctity of age-old orders and hierarchies.
#    - **Charismatic Authority**: Although not detailed in the provided text, this type is based on the personal qualities and leadership traits of an individual which inspire loyalty and devotion.
#
# 2. **Bureaucratic Authority**: Weber views bureaucratic authority as a product of Western rationality that has transformed traditional forms of governance. It is characterized by:
#    - Impartiality and objectivity in administration.
#    - Implementation by trained and paid officials.
#    - Stability and predictability.
#    - A focus on rules and regulations over personal whims.
#
# 3. **Traditional Authority**: This type of authority is deeply rooted in historical practices and beliefs. It is characterized by:
#    - A sense of sacred tradition and the 'holiness' of longstanding customs.
#    - Leadership roles such as patriarchs and patrimonial rulers.
#    - Service to the community or established order rather than to individual interests.
#
# 4. **Impartiality in Authority**: Both legal and traditional authorities require the individual in power to act without personal bias. The holders of such authority:
#    - Must not consider personal relationships or feelings.
#    - Are expected to act without hate, passion, love, or enthusiasm.
#    - Should make decisions based on established rules or traditions, not on personal preference or prejudice.
#
# 5. **Rational-Legal Authority**: A subtype of legal authority where the system of bureaucracy is emphasized. Individuals in positions of power are expected to perform their duties:
#    - Without regard to personal feelings ('sine ira et studio' – without hate and without love).
#    - Based solely on rational application of rules and procedures.
#
# 6. **Concerns of Authority**: Weber's interest in different types of authority is linked to their impact on society. Each type has implications for economic and legal structures:
#    - Traditional authority is linked with economic concerns due to its focus on power and wealth.
#    - Legal/bureaucratic authority is associated with legal concerns due to its focus on power and law.
#
# 7. **Stability and Everydayness**: Weber emphasizes that both legal and traditional authorities contribute to societal stability. This is due to their routine, everyday nature that people come to rely on and expect.
#
# These concepts are central to understanding Weber's sociology of authority and the way different forms of governance operate and maintain societal order.
#
# ================================================================================
#
# Cluster 3 Summary:
# Based on the documents provided, the key concepts conveyed are as follows:
#
# 1. Traditional vs. Bureaucratic Authority:
#    - Weber contrasts traditional authority, which is often inherited and tied to customs, with bureaucratic authority, which is characterized by a formal organizational structure and a set of rules and regulations.
#
# 2. Charismatic Leadership:
#    - Charismatic leadership is presented as being distinct from both traditional and bureaucratic authority. Weber describes it as leadership based on the personal qualities and extraordinary attributes of an individual, rather than on customs or legalities.
#
# 3. Economic Alienation of Charisma:
#    - Weber argues that pure charisma is inherently alien to economic considerations. Charismatic leaders may accept money as gifts or through appropriation, but they fundamentally reject the routine and regulated aspects of everyday economic life.
#
# 4. Rejection of the Impersonal:
#    - The charismatic leader rejects impersonal elements, such as money and bureaucracy, because they are at odds with the personal, individualistic nature of charisma.
#
# 5. The Role of Money:
#    - Weber considers money to be the most abstract and impersonal object in human life, which is why charismatic leaders, who thrive on personal connection and influence, may reject it.
#
# 6. Relationship Between Charisma and Politics:
#    - There's a tension between the desire to be political and apolitical for charismatic leaders. While charismatic leaders may reject politics, there is also a recognition of an inherent antagonism between the two.
#
# 7. Weber's Critique of Bureaucracy:
#    - Weber is described as having spent his life fighting against the 'uncontrollable, limitless domination by bureaucracy', which he saw as a significant threat.
#
# 8. Politik als Beruf (Politics as a Vocation):
#    - Weber discusses the choices between democratic domination by bureaucrats (Berufspolitiker without a calling) and charismatic leadership (Führerdemokratie with a "machine"). The document suggests that while Weber may endorse charismatic leadership, he does so with significant reservations.
#
# 9. The Concept of 'Beruf':
#    - The German term 'Beruf' can be translated as 'calling' or 'vocation'. Weber uses this concept to describe one's personal sense of duty or mission, which is particularly relevant in the context of charismatic leadership.
#
# These concepts are integral to Max Weber's sociology, particularly his theories on authority and leadership. Weber's analysis of charismatic leadership, in particular, is a significant contribution to the understanding of how personal qualities can influence social structures and political systems.
#
# ================================================================================
#
# Cluster 4 Summary:
# Based on the set of documents provided, several key concepts related to Max Weber's work on sociology and political theory are conveyed. Here's a summary of the central ideas:
#
# 1. **Herrschaft**: This German term is central to Weber's sociology and can be translated as rule, dominion, control, power, or sway. Weber defines it as the chance of finding obedience to a command among a specific group of people.
#
# 2. **Macht and Zwang**: These terms refer to power and compulsion, respectively. Weber links Herrschaft with these concepts, suggesting that rulership involves the power to compel obedience.
#
# 3. **State and Force**: Weber acknowledges the role of force in the foundation of states, referencing Trotsky's view that every state is based on force.
#
# 4. **Dominating Classes and Power Possessors**: Weber discusses economic, political, and military domination by certain classes and power possessors, indicating that nations, classes, or persons must submit to their authority.
#
# 5. **Sitte and Konvention**: Weber differentiates between customs (Sitte) and conventions (Konvention), similar to the distinction between nature (physis) and convention (nomos). Sitte has an authoritative quality based on its age and tradition.
#
# 6. **Traditional Laws and Eternal Authority**: Traditional laws, such as those discussed by Hegel, are considered permanent and authoritative, providing a foundation for traditional authority.
#
# 7. **Traditional vs. Bureaucratic Herrschaft**: Weber contrasts the routine nature of traditional authority with the rationally routine nature of bureaucratic authority, both of which emphasize everydayness (Alltäglichkeit).
#
# 8. **Charismatic Leadership**: Weber identifies charismatic leadership as distinct from traditional and bureaucratic dominance due to its extraordinary (Außeralltäglichkeit) nature.
#
# 9. **Continuity and Permanence in Authority**: Both traditional and bureaucratic forms of Herrschaft are characterized by continuity (Stetigkeit) and are considered permanent structures (Dauergebilde) within everyday life (Alltag).
#
# 10. **Capitalism and Order**: Weber argues that economic growth, particularly capitalism, requires rules and order (Alltagskapitalismus), stressing the importance of routine and stability for the functioning of economic systems.
#
# 11. **Obedience and Kantian Ethics**: Weber defines obedience in a Kantian manner, where the individual aligns the content of an order with the maxim of their own behavior.
#
# 12. **Competence in Bureaucratic Herrschaft**: A key distinction between traditional and bureaucratic Herrschaft is that the latter is based on competence and rationality, whereas the former may not emphasize these attributes.
#
# These concepts outline Weber's complex understanding of authority, power, and social structures, and they highlight the ways in which traditional, charismatic, and bureaucratic forms of rule can shape societies and economies.
#
# ================================================================================
#
# Cluster 5 Summary:
# Based on the provided text, the key concepts conveyed include:
#
# 1. Max Weber's Typology of Authority: The text discusses Weber's classification of authority into three types: traditional, bureaucratic, and charismatic.
#
# 2. Charisma: A central focus of the document is the concept of charisma, which Weber views as a form of authority that is personal, extraordinary, and often emerges in times of crisis.
#
# 3. The Charismatic Leader: The text emphasizes the characteristics of charismatic leaders, such as being perceived as extraordinary, having a personal relationship with followers, and the temporary and revolutionary nature of their authority.
#
# 4. Rationality vs. Irrationality: Weber's interest in rationality and its contrast with the irrational elements of charisma is explored.
#
# 5. Institutionalization of Charisma: The transformation of charisma into a more permanent and institutionalized form is a significant notion in Weber's work.
#
# 6. Authority and Leadership: The text distinguishes between the concepts of authority and leadership, particularly in the context of charismatic authority.
#
# 7. The Role of the Political Leader: Weber's analysis of the political leader, particularly the charismatic political leader, is discussed, including the leader's passion, sense of responsibility, and ability to move followers through personal devotion.
#
# 8. Ethics of Conviction vs. Ethics of Responsibility: The text touches on Weber's distinction between Gesinnungsethik (ethics of conviction) and Verantwortungsethik (ethics of responsibility).
#
# 9. Sociological and Political Implications: The document considers the wider sociological and political implications of Weber's analysis of charisma, including its relevance to contemporary society and politics.
#
# 10. Contemporary Interpretations of Charisma: The text references various scholarly opinions on Weber's concept of charisma, including its perceived importance, widespread usage, and potential misinterpretations or oversimplifications.
#
# 11. Weber's Historical Context: The influence of historical events, such as World War I and the German revolutions of 1918-19, on Weber's thinking about charisma and political leadership is mentioned.
#
# Overall, the text explores Weber's nuanced understanding of charisma within his broader sociological framework, its contrast with other forms of authority, and its implications for leadership and politics.
#
# ================================================================================
#
# Cluster 6 Summary:
# The key concepts conveyed in the provided text revolve around Max Weber's sociological and religious theories, particularly focusing on the distinction between the charismatic leader (prophet), asceticism, and mysticism. Here are the key concepts identified from the text:
#
# 1. **Charismatic Leadership**: Weber characterizes the charismatic leader as someone who possesses an extraordinary quality that is perceived as being endowed by a higher power, making them appear as an 'instrument' of God. This leader is followed because their authority is believed to defy conventional or rational understanding.
#
# 2. **Asceticism**: Weber describes the ascetic as actively engaged in the world, working as God's instrument. The ascetic embraces an ethic of self-discipline and restraint, often involving abstention from various worldly pleasures, with the aim of achieving spiritual goals.
#
# 3. **Mysticism**: In contrast to the ascetic, the mystic is seen as a 'vessel', who embraces passivity, allowing God to act through them. The mystic's life is characterized by contemplation and the pursuit of a direct, personal union with the divine ('unio mystica'), often leading to a withdrawal from worldly affairs.
#
# 4. **Irrationality and Anti-rationality**: Weber discusses the irrational or anti-rational nature of both mysticism and charismatic authority. He suggests that the appeal of these forms lies in their departure from rational or everyday norms, tapping into deeper, often inexplicable aspects of human experience.
#
# 5. **Contemplation and Everydayness**: The text highlights the mystic's focus on contemplation, which requires a rejection of daily interests and worldly engagement. This is contrasted with the ascetic's acceptance of the everyday world.
#
# 6. **Disposition to Mysticism as Charisma**: Weber links mysticism to charisma, suggesting that a predisposition to mysticism is a type of individual charisma. Mystics, prophets, and holy men are grouped together in their shared rejection of the everyday world and their reliance on personal charisma.
#
# 7. **Innerworldly vs. Otherworldly Orientation**: The text references Weber's distinction between 'innerworldly asceticism' and 'otherworldly mysticism'. Calvin's active engagement with the world is contrasted with Luther's passive mystical experience. This concept deals with the different ways religious individuals relate to the world, either by actively shaping it or by seeking a mystical separation from it.
#
# 8. **Unio Mystica and Weltflucht**: The 'unio mystica' is the mystical union with God, a key experience for Lutherans according to Weber. 'Weltflucht', or 'world flight', is the mystic's tendency to flee from the world, as opposed to the ascetic's 'Weltablehnung', or 'world rejection', which involves a more active stance.
#
# 9. **Fluidity Between Mystic and Ascetic**: Finally, the text notes that the distinction between the mystic and the ascetic is fluid, implying that there can be overlap and that these categories may not be strictly separate.
#
# These concepts provide insights into Weber's analysis of religious authority, the different ways individuals pursue spiritual goals, and the sociological implications of such pursuits.
#
# ================================================================================
#
# Cluster 7 Summary:
# The key concepts conveyed in the provided documents are:
#
# 1. The foundational role of force in the establishment of states: The quote from Trotsky, "Every state is founded on force," highlights the idea that the creation and maintenance of states are often associated with the use of power and violence.
#
# 2. The legitimate monopoly on physical force: The mention of the state having the "legitimate monopoly on physical force" reflects a core concept in political sociology and the theory of the state, particularly associated with the work of Max Weber. It indicates that one of the defining characteristics of a state is its unique and legitimate authority to use force to maintain order and enforce laws within its territory.
#
# 3. The concept of legitimate force: This is closely related to the above point but emphasizes the legitimacy aspect. The state's claim to a "monopoly [of] legitimate force" suggests that the state's use of force is accepted and recognized as rightful and lawful, as opposed to the use of force by non-state actors, which is typically seen as illegitimate or illegal.
#
# These concepts are central to the understanding of state power and authority and are often discussed in the context of political theory and the philosophy of law. Max Weber's contribution to this topic is particularly significant as he was one of the first to systematically articulate the relationship between the state and the legitimate use of force.
#
# ================================================================================
#
# Cluster 8 Summary:
# The key concepts conveyed in the provided document excerpt are:
#
# 1. Influence on Divine Entities: The text discusses whether it is appropriate or effective to try to influence a specific god or daemon using force (compulsion) or supplication (pleading).
#
# 2. Pragmatic Approach: The question of influencing a divine entity is presented as a pragmatic issue, primarily concerning the likelihood of success rather than the morality or ethics of the attempt.
#
# 3. Power Preservation: The analogy between a magician's charisma and a god's power suggests that both entities have a reputation or strength that needs to be maintained. The implication is that their willingness or ability to be influenced may be tied to the preservation of their power or status.
#
# 4. Charisma and Power: The document contrasts the personal attribute of charisma in a human (the magician) with the divine attribute of power in a god, suggesting a parallel in how they exert influence or command respect.
#
# The document seems to be discussing themes related to religious or magical practices and the considerations involved in attempting to engage with supernatural forces. The focus on success implies a utilitarian viewpoint, where the value of a religious or magical act is judged based on its outcomes.
#
# ================================================================================
#
# Cluster 9 Summary:
# The key concepts conveyed in these documents, which refer to Max Weber's writings on charisma, particularly in his seminal work "Wirtschaft und Gesellschaft" (Economy and Society), are as follows:
#
# 1. Charismatic Leadership: Weber explores the concept of charisma as it pertains to leaders who possess an 'extraordinary' quality that inspires personal devotion in their followers.
#
# 2. Miracles and Heroic Acts: The charismatic leader is perceived as capable of performing miracles or heroic feats, which are central to the leader's appeal and authority.
#
# 3. Personal Devotion: Followers have a personal devotion to the charismatic leader, recognizing and acknowledging the leader’s special qualities and characteristics.
#
# 4. Recognition by Followers: Weber emphasizes that the charismatic leader's authority is contingent on the recognition and validation by their followers.
#
# 5. Charisma and Religion: The charismatic leader is often seen as chosen or favored by divine grace, and there is a connection between charisma and religious figures, including prophets and magicians.
#
# 6. Fluid Distinction: Weber notes that the distinction between religious figures such as priests and magicians is fluid, with both potentially exhibiting charisma.
#
# 7. Source of Charisma: Weber acknowledges Rudolf Sohm's influence on his understanding of charisma, which he applied to his studies of early Christianity.
#
# 8. Prophet vs. Priest: Weber differentiates between prophets, who are "personal charisma carriers" with a divine calling, and priests, whose authority is derived from their societal position rather than personal charisma.
#
# 9. Jesus and Old Testament Prophets: Weber places Jesus within the tradition of Old Testament prophets, highlighting the tenuous nature of their authority and their direct relationship with God.
#
# 10. Faith and Magical Capability: Weber suggests that in the New Testament, faith in the 'shepherds of the soul' with a specific charisma can be seen as a surrogate for magical capabilities.
#
# 11. The Prophet's Role: Weber defines a prophet as an individual who, by virtue of their mission, proclaims a religious doctrine or divine command, emphasizing the personal nature of their charisma.
#
# These concepts form the basis of Weber's sociological analysis of charisma and its function within society, particularly in the context of religious communities and leadership.
#
# ================================================================================
# C:\Users\wasim\AppData\Local\Temp\ipykernel_24820\3854131076.py:63: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for cluster_id, summary in cluster_summaries.iteritems():
# C:\Users\wasim\AppData\Local\Temp\ipykernel_24820\3854131076.py:69: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   all_summaries = [summary for cluster_id, summary in cluster_summaries.iteritems()]

# %%
# Summarization template for the combined summaries
summary_template = """The following points summarize the key themes and sub-themes from a set of documents:
{points}
Please create a concise summary that includes all the major themes in a fraction of the original text's length."""

# Create a prompt using the template
summary_prompt = PromptTemplate.from_template(summary_template.format(points=combined_summaries))

# Summarize the combined summaries
concise_summary = llm.run(summary_prompt)

print(concise_summary)
# Out:
# The main themes identified from the set of documents are:
#
# 1. Max Weber's influence on management and organizational theory, including his conceptualization of authority and its relevance in the 21st century.
# 2. The three types of authority outlined by Weber - Traditional, Rational-Legal, and Charismatic, and their contrasting characteristics, roles, and impacts.
# 3. The process of "routinizing" Charismatic authority, its transient nature in times of crisis, and its role as a form of rebellion.
# 4. The transformation of authority structures in the industrial and information age sparked by technological advancements.
# 5. The concept of self-managing organizational forms and the shift in control from traditional management to workers.
# 6. Weber's Iron Cage concept and its implications in modern organizational practices.
# 7. The paradox of empowerment potentially leading to stricter control within organizations.
# 8. The impact of these concepts on contemporary understanding of complex organizational phenomena and the related themes in academia, human resources, industrial relations, management education, and research publication.
# 9. The development, evolution, and applicability of charismatic leadership in today's rapidly changing environments.
# 10. Weber's biography, his academic journey, intense writing productivity, and his significant contributions to various fields.
# 11. The role of context in charismatic leadership, especially in dynamic or crisis situations, and the ongoing academic debate on Weber's theory of charismatic authority.

# %%
from transformers import PegasusTokenizer, PegasusForConditionalGeneration
from pdfminer.high_level import extract_text
import language_tool_python

# Load the tokenizer and model
tokenizer = PegasusTokenizer.from_pretrained("google/pegasus-xsum")
model = PegasusForConditionalGeneration.from_pretrained("google/pegasus-xsum")

def generate_summary(paragraphs):
    summaries = []
    for paragraph in paragraphs:
        tokens = tokenizer(paragraph, truncation=True, padding="longest", max_length=512, return_tensors="pt")
        summary_tokens = model.generate(**tokens)
        summary = tokenizer.decode(summary_tokens[0], skip_special_tokens=True)
        summaries.append(summary)
    return summaries

def extract_and_summarize(pdf_path):
    text = extract_text(pdf_path)
    paragraphs = text.split('\n\n')
    filtered_paragraphs = [p for p in paragraphs if len(p.split()) >= 50]

    print(f"Number of paragraphs extracted: {len(filtered_paragraphs)}")
    print("Extraction complete. Preprocessing text...")

    summaries = generate_summary(filtered_paragraphs)
    combined_summary = ' '.join(summaries)

    return combined_summary
# Out:
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-xsum and are newly initialized: ['model.encoder.embed_positions.weight', 'model.decoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Run the summary function
pdfpath = choose_file()
summary = extract_and_summarize(pdfpath)

print(summary)
# Out:
# Number of paragraphs extracted: 38
# Extraction complete. Preprocessing text...
# The sociologist Max Weber considered three types of authority: traditional, bureaucratic and charismatic. In our series of letters from African journalists, filmmaker and columnist Ahmedou Ould-Abdallah looks at Max Weber’s interest in bureaucratic authority. There are two types of authority: legal authority and traditional authority. There are three types of charisma: charisma as a force for good, charisma as a force for evil, and charisma as a force for good. Weber was interested in charisma as a type of Herrschaft. This article is the first in a series on Weber’s theories of charisma. Herrschaft can be rendered as ‘rule’, ‘dominion’, ‘control’, ‘power’ or ‘sway’. Weber often refers to Herrschaft as ‘autorit at’ or ‘authority’. In our series of letters from German journalists, film-maker and columnist Paul Honigsheim looks at one of the greatest preoccupations of German intellectuals of the 20th Century, Emil Weber. There are two types of holiness. The authority on Sitte and the Laws of the underworld are eternal, according to Hegel, the authority on Sitte and the Laws of the underworld are eternal, according to Weber, the authority on Sitte and the Laws of the underworld are eternal, according to Weber, the authority on Sitte and the In his lecture on Rechtphilosophie in Heidelberg in 1817, Hegel speaks of the Gesetz as eternal, a point that he makes explicit in his lectures on Rechtphilosophie in Heidelberg in 1817. The possessor of traditional authority cannot have regard for individual people. The relationship between traditional leadership and bureaucratic authority is one of the most important in politics. In Wirtschaft und Gesellschaft Weber makes an important distinction between traditional and bureaucratic Herrschaft. In ‘Die Herrschaft’ he distinguishes between the charismatic leader and the ‘J unger’disciple: the charismatic leader is ‘spezifisch auerallt aglich-specific ally extraordinary’, while the ‘J unger’disciple is Weber’s theory of charisma is an important part of our understanding of leadership. The charisma of a charismatic leader is dependent on the recognition of his followers. In his seminal work on charisma, Dietrich Weber considers the role of the prophet in the Christian faith. Weber describes the charismatic leader as a man who believes and is believed in. Weber draws the connection between the prophet, the mystic and the charismatic leader. In Weber’s view, charismatic leaders reject any type of everyday routine or regulated economy: that is, they reject anything along the lines of a traditional or rational ‘Alltagswirtschaft’: that is, they reject any type of everyday routine and regulated economy. In his book Politik als Beruf (1992b, 191), the German philosopher and politician Max Weber argues that the true political leader is not a demagogue, but a charis- matic leader. In his seminal work Verantwortungssethik, German philosopher and politician Max Weber argued that the true leader must take responsibility for his actions. Weber believed that politics should be based on the ethics of conviction. In his book Politik als Beruf, Manfred Weber argued that the German political establishment had become too bureaucratic. Weber’s Politik als Beruf is one of the most important political works of the 20th Century. In his seminal work, The Power of the Charismatic Leader, Hans-Joachim Weber argued that the power of the charismatic leader was not always predictable. Weber was one of the most influential sociologists of the 20th Century. Weber defines obedience in a particularly Kantian way – that the person who obeys the order makes the content of that order the same as the willing of the maxim of one’s own behavior (1976: 123). In the second part of our series of letters from Russian journalists, Andrei Trotzkij, editor of the opposition newspaper Gazeta Prawna, argues that the state has a legitimate monopoly on physical force. Weber used the phrases ‘sine ira ac (et) studio’, ‘sine reinen Typen der Her ...

# %%
from transformers import PegasusTokenizer, PegasusForConditionalGeneration
from pdfminer.high_level import extract_text
import torch

# Load the tokenizer and model
CUDA_LAUNCH_BLOCKING=1
tokenizer = PegasusTokenizer.from_pretrained("google/pegasus-xsum")
model = PegasusForConditionalGeneration.from_pretrained("google/pegasus-xsum")

# Enable GPU if it's available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

def generate_summary(paragraphs, batch_size=4):
    summaries = []
    for i in range(0, len(paragraphs), batch_size):
        batch = paragraphs[i:i+batch_size]
        tokens = tokenizer(batch, truncation=True, padding=True, max_length=512, return_tensors="pt").to(device)
        summary_tokens = model.generate(**tokens)
        batch_summaries = [tokenizer.decode(t, skip_special_tokens=True) for t in summary_tokens]
        summaries.extend(batch_summaries)
    return summaries

def extract_and_summarize(pdf_path):
    text = extract_text(pdf_path)
    paragraphs = text.split('\n\n')
    filtered_paragraphs = [p for p in paragraphs if len(p.split()) >= 50]

    print(f"Number of paragraphs extracted: {len(filtered_paragraphs)}")
    print("Extraction complete. Preprocessing text...")

    summaries = generate_summary(filtered_paragraphs, batch_size=4)  # Adjust the batch size based on your GPU's memory
    combined_summary = ' '.join(summaries)

    return combined_summary

pdfpath = choose_file()
summary = extract_and_summarize(pdfpath)

print(summary)
# Out:
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-xsum and are newly initialized: ['model.encoder.embed_positions.weight', 'model.decoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[25], line 12
#      10 # Enable GPU if it's available
#      11 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# ---> 12 model = model.to(device)
#      14 def generate_summary(paragraphs, batch_size=4):
#      15     summaries = []
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\modeling_utils.py:2271, in PreTrainedModel.to(self, *args, **kwargs)
#    2266     if dtype_present_in_args:
#    2267         raise ValueError(
#    2268             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    2269             " `dtype` by passing the correct `torch_dtype` argument."
#    2270         )
# -> 2271 return super().to(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1160, in Module.to(self, *args, **kwargs)
#    1156         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1157                     non_blocking, memory_format=convert_to_format)
#    1158     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1160 return self._apply(convert)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:810, in Module._apply(self, fn, recurse)
#     808 if recurse:
#     809     for module in self.children():
# --> 810         module._apply(fn)
#     812 def compute_should_use_set_data(tensor, tensor_applied):
#     813     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     814         # If the new tensor has compatible tensor type as the existing tensor,
#     815         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     820         # global flag to let the user control whether they want the future
#     821         # behavior of overwriting the existing tensor or not.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:810, in Module._apply(self, fn, recurse)
#     808 if recurse:
#     809     for module in self.children():
# --> 810         module._apply(fn)
#     812 def compute_should_use_set_data(tensor, tensor_applied):
#     813     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     814         # If the new tensor has compatible tensor type as the existing tensor,
#     815         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     820         # global flag to let the user control whether they want the future
#     821         # behavior of overwriting the existing tensor or not.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:833, in Module._apply(self, fn, recurse)
#     829 # Tensors stored in modules are graph leaves, and we don't want to
#     830 # track autograd history of `param_applied`, so we have to use
#     831 # `with torch.no_grad():`
#     832 with torch.no_grad():
# --> 833     param_applied = fn(param)
#     834 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     835 if should_use_set_data:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1158, in Module.to.<locals>.convert(t)
#    1155 if convert_to_format is not None and t.dim() in (4, 5):
#    1156     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1157                 non_blocking, memory_format=convert_to_format)
# -> 1158 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %% [markdown]
# ## Conclusion
# The combination of these steps forms a pipeline for text summarization. The preprocessed text is used to build a similarity matrix, which is then used by the TextRank algorithm to rank sentences by importance. The most important sentences are selected to form a summary of the original text.
#
# For the most effective similarity matrix in the context of TextRank, the cosine similarity between Word2Vec sentence embeddings is a strong choice, as it captures the semantic similarity between sentences. However, depending on the specific use case and the nature of the text, other methods like TF-IDF or BERT embeddings could be considered for potentially better performance.

# %% [markdown]
# ## References
#
# - Mihalcea, R., & Tarau, P. (2004). TextRank: Bringing Order into Texts. Association for Computational Linguistics.
# - Erkan, G., & Radev, D. R. (2004). LexRank: Graph-based Lexical Centrality as Salience in Text Summarization. Journal of Artificial Intelligence Research.
# - Luhn, H. P. (1958). The automatic creation of literature abstracts. IBM Journal of research and development.
# - Deerwester, S., Dumais, S. T., Furnas, G. W., Landauer, T. K., & Harshman, R. (1990). Indexing by Latent Semantic Analysis. Journal of the American Society for Information Science.
# - Radev, D. R., Jing, H., Styś, M., & Tam, D. (2004). Centroid-based summarization of multiple documents. Information Processing & Management.
# - Steinberger, J., & Jezek, K. (2004). Using Latent Semantic Analysis in Text Summarization and Summary Evaluation. Proceedings of ISIM.
# - Brown, P. F., Della Pietra, V. J., deSouza, P. V., Lai, J. C., & Mercer, R. L. (1992). Class-Based n-gram Models of Natural Language. Computational Linguistics.
# - Raffel, C., Shazeer, N., Roberts, A., Lee, K., Narang, S., Matena, M., Zhou, Y., Li, W., & Liu, P. J. (2020). Exploring the Limits of Transfer Learning with a Unified Text-to-Text Transformer. Journal of Machine Learning Research.
# - Lewis, M., Liu, Y., Goyal, N., Ghazvininejad, M., Mohamed, A., Levy, O., Stoyanov, V., & Zettlemoyer, L. (2020). BART: Denoising Sequence-to-Sequence Pre-training for Natural Language Generation, Translation, and Comprehension. Association for Computational Linguistics.
# - Zhang, J., Zhao, Y., Saleh, M., & Liu, P. J. (2020). PEGASUS: Pre-training with Extracted Gap-sentences for Abstractive Summarization. Association for Computational Linguistics.
# - Brown, T., Mann, B., Ryder, N., Subbiah, M., Kaplan, J. D., Dhariwal, P., Neelakantan, A., Shyam, P., Sastry, G., Askell, A., Agarwal, S., Herbert-Voss, A., Krueger, G., Henighan, T., Child, R., Ramesh, A., Ziegler, D. M., Wu, J., Winter, C., Hesse, C., Chen, M., Sigler, E., Litwin, M., Gray, S., Chess, B., Clark, J., Berner, C., McCandlish, S., Radford, A., Sutskever, I., & Amodei, D. (2020). Language Models are Few-Shot Learners. arXiv preprint arXiv:2005.14165.
